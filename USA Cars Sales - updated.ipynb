# %%
#Import some extention libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import xlsxwriter

# %%
USACarsDatasets = pd.read_excel(r"C:\Users\Sales\USACarsDatasets.xlsx")

# %%
USACarsDatasets.isnull().sum()
# Out:
# Unnamed: 0      0
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           0
# vin             0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64

# %%
USACarsDatasets.isnull().any()
# Out:
# Unnamed: 0      False
# price           False
# brand           False
# model           False
# year            False
# title_status    False
# mileage         False
# color           False
# vin             False
# lot             False
# state           False
# country         False
# condition       False
# dtype: bool

# %%
USACarsDatasets.shape
# Out:
# (2499, 13)

# %%
USACarsDatasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2499 non-null   int64
#  1   price         2499 non-null   int64
#  2   brand         2499 non-null   object
#  3   model         2499 non-null   object
#  4   year          2499 non-null   int64
#  5   title_status  2499 non-null   object
#  6   mileage       2499 non-null   int64
#  7   color         2499 non-null   object
#  8   vin           2499 non-null   object
#  9   lot           2499 non-null   int64
#  10  state         2499 non-null   object
#  11  country       2499 non-null   object
#  12  condition     2499 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 253.9+ KB

# %%
USACarsDatasets.describe()
# Out:
#         Unnamed: 0         price         year       mileage           lot
# count  2499.000000   2499.000000  2499.000000  2.499000e+03  2.499000e+03
# mean   1249.000000  18767.671469  2016.714286  5.229869e+04  1.676914e+08
# std     721.543484  12116.094936     3.442656  5.970552e+04  2.038772e+05
# min       0.000000      0.000000  1973.000000  0.000000e+00  1.593488e+08
# 25%     624.500000  10200.000000  2016.000000  2.146650e+04  1.676253e+08
# 50%    1249.000000  16900.000000  2018.000000  3.536500e+04  1.677451e+08
# 75%    1873.500000  25555.500000  2019.000000  6.347250e+04  1.677798e+08
# max    2498.000000  84900.000000  2020.000000  1.017936e+06  1.678055e+08

# %%
USACarsDatasets['price'].describe()
# Out:
# count     2499.000000
# mean     18767.671469
# std      12116.094936
# min          0.000000
# 25%      10200.000000
# 50%      16900.000000
# 75%      25555.500000
# max      84900.000000
# Name: price, dtype: float64

# %%
USACarsDatasets['price'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
USACarsDatasets['price'].plot(kind='box',vert=False,figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
USACarsDatasets['price'].plot(kind='density',figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ax = USACarsDatasets['price'].plot(kind='density',figsize=(14,6)) # kde
ax.axvline(USACarsDatasets['price'].mean(),color='red')
ax.axvline(USACarsDatasets['price'].median(),color='green')

# %%
corr = USACarsDatasets.corr()

corr
# Out:
#             Unnamed: 0     price      year   mileage       lot
# Unnamed: 0    1.000000  0.098417  0.244921 -0.129258  0.012577
# price         0.098417  1.000000  0.418274 -0.400838  0.159369
# year          0.244921  0.418274  1.000000 -0.594686  0.164582
# mileage      -0.129258 -0.400838 -0.594686  1.000000 -0.130475
# lot           0.012577  0.159369  0.164582 -0.130475  1.000000

# %%
fig = plt.figure(figsize=(8,8))
plt.matshow(corr,cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %%
USACarsDatasets.plot(kind='scatter',x='year', y='price',figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
ax = USACarsDatasets[['year','price']].boxplot(by='year',figsize=(15,6))
ax.set_ylabel('price')
# Out:
# Text(0, 0.5, 'price')
